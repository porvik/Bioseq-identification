# %% [markdown]
# # Visualizacion
#
# ```{figure} data:image/png;base64,...
# :name: fig-biodiv
# :width: 300px
# :align: left
#
# Biodiversidad
# ```

# %% [markdown]
# ```{figure} data:image/png;base64,...
# :name: fig-tax
# :align: left
# :width: 300px
#
# Taxonomia
# ```
